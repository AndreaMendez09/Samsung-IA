# %%
# Coding Practice #0615
#----------------------------------------------------------------------------------
import numpy as np
import cv2

from google.colab.patches import cv2_imshow

# Go to the directory where the data file is located. 
# os.chdir(r'~~')                     				  # Please, replace the path with your own.   

# 1. Working with image data: 

# 1.1. Open an image in color (BGR) and show it. 
img_bgr = cv2.imread('/content/picture_Butterfly.jpg',1)                                 # Open as a color image.
print("Shape of the image read in color : ", img_bgr.shape)                     # Height, width, channel.

cv2_imshow(img_bgr)
cv2.waitKey(0)                                                                      # Wait until a key is pressed.
cv2.destroyAllWindows()                                                             # Close the open window.
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 1.2. Convert to B/W (gray scale) and show it.
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY) 

cv2_imshow(img_gray)
cv2.waitKey(0)                                                                      # Wait until a key is pressed.
cv2.destroyAllWindows()                                                             # Close the open window.
# Out:
# <PIL.Image.Image image mode=L size=1920x1440 at 0x7F157721A6D8>

# %%
# 1.3. Convert to HSV and split the channels: Hue, Saturation, Value. 
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV) 
h = img_hsv[:,:,0]
s = img_hsv[:,:,1]
v = img_hsv[:,:,2]

hue = cv2.merge([h,h,h])
sat = cv2.merge([s,s,s])
val = cv2.merge([v,v,v])

print("The Hue Channel")
cv2_imshow(hue)
cv2.waitKey(0)                                                                      # Wait until a key is pressed.
cv2.destroyAllWindows()                                                             # Close the open window.

print("The Saturation Channel")
cv2_imshow(sat)
cv2.waitKey(0)                                                                      # Wait until a key is pressed.
cv2.destroyAllWindows()                                                             # Close the open window.

print("The Value Channel")
cv2_imshow(val)
cv2.waitKey(0)                                                                      # Wait until a key is pressed.
cv2.destroyAllWindows()                                                             # Close the open window.
# Out:
# Output hidden; open in https://colab.research.google.com to view.
