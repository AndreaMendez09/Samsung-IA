# %% [markdown]
# ## Ejercicio de codificación #0214

# %% [markdown]
# ### 1. Visualización con Seaborn (más ejemplos):

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')           # desactivar las alarmas.

# %% [markdown]
# #### 1.1. Matriz de diagramas de dispersión:

# %%
# Leer los datos 'iris' desde la biblioteca.
dat = sns.load_dataset('iris')

# %%
# Una matriz de diagramas de dispersión.
sns.pairplot(dat)
plt.show()

# %%
# Colorea los marcadores con 'especies'.
sns.pairplot(dat, hue='species')
plt.show()

# %%
# Colorea los marcadores con 'especies'. Aplica una paleta.
sns.pairplot(dat, hue='species', palette='coolwarm')
plt.show()

# %% [markdown]
# #### 1.2. PairGrid:

# %%
# Una matriz de diagramas de dispersión.
g=sns.PairGrid(dat)
g.map(plt.scatter)
plt.show()

# %%
# Una matriz de diferntes diagramas.
g=sns.PairGrid(dat)
g.map_diag(sns.distplot, color='orange')         # Diagonal = histograma.
g.map_upper(plt.scatter, color='green')          # Triángulo superior = diagrma de dispersión.
g.map_lower(sns.kdeplot, color='blue')           # Triángulo inferior = KDE.
plt.show()

# %% [markdown]
# #### 1.3. Rejilla de facetas (FacetGrid):

# %%
# Múltiples histogramas.
g=sns.FacetGrid(data=dat, col='species')
g.map(sns.distplot, 'petal_length')
plt.show()

# %%
# Múltiples histogramas.
g=sns.FacetGrid(data=dat, row='species')
g.map(sns.distplot, 'petal_length')
plt.show()

# %%
# Múltiples diagramas de dispersión.
g=sns.FacetGrid(data=dat, col='species')
g.map(plt.scatter, 'petal_length', 'petal_width',color='orange')
plt.show()

# %% [markdown]
# #### 1.4. Mapa de calor:

# %%
# Leer los datos 'mpg' desde la librería. 
dat = sns.load_dataset('mpg')

# %%
# Matriz de correlación.
x = dat.corr()
x
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
# Mapa de calor por defecto.
sns.heatmap(x)
plt.show()

# %%
# Mapa de calor.
# Utilizar 'cmap' en lugar de 'palette'.
sns.heatmap(x, cmap = 'coolwarm')
plt.show()

# %%
# Mapa de calor.
# Ajustar el centro.
sns.heatmap(x, cmap = 'coolwarm', center=-1)
plt.show()
