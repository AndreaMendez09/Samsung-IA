# %% [markdown]
# ## Prueba #0302

# %% [markdown]
# ### "Especificación de tornillos"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Responda las siguientes preguntas proporcionando código Python:

# %% [markdown]
# Según la hoja de especificaciones, el peso medio de los tornillos es $\mu = 30$ gr con $\sigma = 2$ gr. <br>
# Suponga que se extrae una muestra de 50 tornillos.

# %%
mu = 30
sigma = 2
n = 50
df = n-1

# %% [markdown]
# 1). ¿Cuál es la probabilidad de que la media muestral esté **entre** 29.8 gr y 30.2 gr? (utilice la normal estándar  y la $t$ de Student)

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %%
# Usando normal estándar.
st.norm.cdf(30.2,loc = mu, scale=(sigma/np.sqrt(n))) - st.norm.cdf(29.8,loc = mu, scale=(sigma/np.sqrt(n)))
# Out:
# 0.520499877813045

# %%
# Usando t de Student.
st.t.cdf(30.2,df,mu,(sigma/np.sqrt(n))) - st.t.cdf(29.8,df,mu,(sigma/np.sqrt(n)))
# Out:
# 0.5171504292916964

# %% [markdown]
# 2). ¿Cuál es la probabilidad de que la media de la muestra sea **mayor** que 30,5 gr? (utilice normal estándar y $t$ de Student)

# %%
# Usando normal estándar.
1 - st.norm.cdf(30.5,loc = mu, scale=(sigma/np.sqrt(n)))#Señalizamos el contrario con el -1
# Out:
# 0.0385499358717708

# %%
# Usando t de Student.
1 - st.t.cdf(30.5,df,mu,(sigma/np.sqrt(n)))#Señalizamos el contrario con el -1
# Out:
# 0.04166307987075457
