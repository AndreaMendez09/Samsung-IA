# %% [markdown]
# ## Ejercicio de codificación #0410

# %% [markdown]
# ### 1. Regresiones regularizadas:

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso

# %% [markdown]
# #### 1.1. Leer los datos:
#
# El conjunto de datos proviene de 1974 MotoTrend US Magazine.

# %%
# Ir al directorio que contiene el fichero 
# os.chdir(r'~~')                # Reemplazar por la ruta adecuada

# %%
df = pd.read_csv('data_mtcars.csv', header='infer')

# %%
df.shape

# %%
df.head(5)

# %%
# Separe en X e Y.

# %%
# Divida el conjunto de datos (entrenamiento y test).

# %% [markdown]
# #### 1.2. Regresión de Ridge:

# %%
# Defina un rango de valores para lambda

# %%
bestRsq = 0.0                                                # Para contener el mejor R^2.
bestLambda = 0.0                                             # Para contener la mejor lambda.

# Evalúe el rendimiento (R^2) para los valores de lambda y quédese con el mejor

# Ejecución final con bestLambda (entrene con Ridge y el mejor valor de lambda encontrado).

# %%
# Muestre la intersección.

# %%
# Mostrar otros parámetros.

# %% [markdown]
# NOTA: En Ridge, incluso cuando $\lambda$ es grande ningún parámetro es exactamente 0.

# %% [markdown]
# #### 1.3. Regresión de Lasso:

# %%
# Define un rango de valores para lambda

# %%
bestRsq = 0.0                                                # Para contener el mejor R^2.
bestLambda = 0.0                                             # Para contener la mejor lambda.

# Evalúe el rendimiento (R^2) para los valores de lambda y quédese con el mejor

# Ejecución final con bestLambda (entrene con Lasso y el mejor valor de lambda encontrado).

# %%
# Muestre la intersección.

# %%
# Mostrar otros parámetros.

# %% [markdown]
# NOTA: Lasso puede hacer que algunos parámetros sean exactamente 0 cuando $ \ lambda $ es lo suficientemente grande.
