# %% [markdown]
# ## Ejercicio de codificación #0507

# %% [markdown]
# ### 1. Conjunto de votaciones:

# %%
import numpy as np
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier
from sklearn import metrics
from sklearn.datasets import load_breast_cancer
warnings.filterwarnings(action='ignore')                  # Desactivar las advertencias.

# %% [markdown]
# #### 1.1.Leer los datos:

# %%
# Cargar los datos.
data = load_breast_cancer()

# %%
# Variables explicativas
X = data['data']
print(data['feature_names'])

# %%
X.shape

# %%
# Variable de respuesta
# Volver a etiquetar de forma que 0 = 'benign' y 1 = malignant.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1234)

# %% [markdown]
# #### 1.2. Predicción con estimador individual:

# %%
# Árbol de clasificación.

# %%
# Clasificación con KNN

# %%
# Clasificación con regresión logística.

# %% [markdown]
# #### 1.3. Predicción con un conjunto de votantes:

# %%
# voting = 'hard'.

# %%
# voting = 'soft'.
