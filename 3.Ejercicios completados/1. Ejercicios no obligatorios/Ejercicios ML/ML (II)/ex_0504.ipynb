# %% [markdown]
# ## Ejercicio de codificación #0504

# %% [markdown]
# ### 1. Clasificación con SVM:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.datasets import load_iris
warnings.filterwarnings(action='ignore')                  # Desactiva las advertencias.
# %matplotlib inline

# %% [markdown]
# #### 1.1. Leer los datos:

# %%
# Cargar datos.
data = load_iris()

# %%
# Variables explicativas.
X = data['data']
columns = list(data['feature_names'])
print(columns)

# %%
# Variable respuesta.
Y = data['target']
labels = list(data['target_names'])
print(labels)

# %%
# Dividir en entrenamiento y test

# %% [markdown]
# #### 1.2. Optimización de hiperparámetros SVM (kernel RBF):

# %% [markdown]
# C     : Parámetro de penalización. <br>
# gamma : parámetro del kernel ($\gamma$).

# %%
# Optimización de ambos hiperparámetros con GridSearch

# %%
# Imprimir por pantalla los mejores valores de los hiperparámetros

# %%
# Test con los mejores valores de los hiperparámetros

# %% [markdown]
# #### 1.3. Optimización de hiperparámetros SVM (kernel polinimial):

# %%
# Optimización de ambos hiperparámetros con GridSearch

# %%
# Imprimir por pantalla los mejores valores de los hiperparámetros

# %%
# Test con los mejores valores de los hiperparámetros
